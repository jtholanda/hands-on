# %% [markdown]
# # Projeto final
#
# Bem vindo ao projeto final do curso/módulo de Pandas.
# Neste projeto, você deve responder a um conjunto de perguntas feitas a dois conjuntos de dados:
#
# 1. [Obesity among adults by country, 1975-2016](https://www.kaggle.com/amanarora/obesity-among-adults-by-country-19752016/)
# 2. [GDP Per Person (1901-2011)](https://www.kaggle.com/divyansh22/gdp-per-person-19012011?select=GDP.csv)
#
# Tais conjuntos de dados são públicos foram publicados no Kaggle. Mais instruções sobre cada um deles podem ser encontrados nos links acima. Você também os encontrará na pasta `Datasets`, dentro de nossas apostilas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Perguntas - Obesity among adults by country, 1975-2016

# %%
df_obesity = pd.read_csv("Datasets/obesity_cleaned.csv")
df_obesity.head(10)
# Out:
#    Unnamed: 0      Country  Year    Obesity (%)         Sex
# 0           0  Afghanistan  1975  0.5 [0.2-1.1]  Both sexes
# 1           1  Afghanistan  1975  0.2 [0.0-0.6]        Male
# 2           2  Afghanistan  1975  0.8 [0.2-2.0]      Female
# 3           3  Afghanistan  1976  0.5 [0.2-1.1]  Both sexes
# 4           4  Afghanistan  1976  0.2 [0.0-0.7]        Male
# 5           5  Afghanistan  1976  0.8 [0.2-2.0]      Female
# 6           6  Afghanistan  1977  0.6 [0.2-1.2]  Both sexes
# 7           7  Afghanistan  1977  0.2 [0.0-0.7]        Male
# 8           8  Afghanistan  1977  0.9 [0.3-2.1]      Female
# 9           9  Afghanistan  1978  0.6 [0.2-1.3]  Both sexes

# %%
type(df_obesity["Sex"])
# Out:
# pandas.core.series.Series

# %%
type(df_obesity[["Sex"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# transpose
df_obesity[["Sex"]].transpose()
# Out:
#           0     1       2           3     4       5           6     7      \
# Sex  Both sexes  Male  Female  Both sexes  Male  Female  Both sexes  Male
#
#       8           9      ...   24560       24561 24562   24563       24564  \
# Sex  Female  Both sexes  ...  Female  Both sexes  Male  Female  Both sexes
#
#     24565   24566       24567 24568   24569
# Sex  Male  Female  Both sexes  Male  Female
#
# [1 rows x 24570 columns]

# %%
df_obesity[["Year"]].shift(1)
# Out:
#          Year
# 0         NaN
# 1      1975.0
# 2      1975.0
# 3      1975.0
# 4      1976.0
# ...       ...
# 24565  2015.0
# 24566  2015.0
# 24567  2015.0
# 24568  2016.0
# 24569  2016.0
#
# [24570 rows x 1 columns]

# %%
# shift
df_obesity[["Year"]] - df_obesity[["Year"]].shift(1)
# Out:
#        Year
# 0       NaN
# 1       0.0
# 2       0.0
# 3       1.0
# 4       0.0
# ...     ...
# 24565   0.0
# 24566   0.0
# 24567   1.0
# 24568   0.0
# 24569   0.0
#
# [24570 rows x 1 columns]

# %%
df_obesity["Year"].isin([1900,1901,1975])
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 24565    False
# 24566    False
# 24567    False
# 24568    False
# 24569    False
# Name: Year, Length: 24570, dtype: bool

# %%
# retorna arrays
df_obesity["Year"].values
# Out:
# array([1975, 1975, 1975, ..., 2016, 2016, 2016], dtype=int64)

# %%
df_obesity.values
# Out:
# array([[0, 'Afghanistan', 1975, '0.5 [0.2-1.1]', 'Both sexes'],
#        [1, 'Afghanistan', 1975, '0.2 [0.0-0.6]', 'Male'],
#        [2, 'Afghanistan', 1975, '0.8 [0.2-2.0]', 'Female'],
#        ...,
#        [24567, 'Zimbabwe', 2016, '15.5 [12.0-19.2]', 'Both sexes'],
#        [24568, 'Zimbabwe', 2016, '4.7 [2.5-8.0]', 'Male'],
#        [24569, 'Zimbabwe', 2016, '25.3 [19.1-32.0]', 'Female']],
#       dtype=object)

# %%
df_obesity.index
# Out:
# RangeIndex(start=0, stop=24570, step=1)

# %%
df_obesity.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Year', 'Obesity (%)', 'Sex'], dtype='object')

# %%
for idx, rows in df_obesity.iterrows():
    print(idx, rows["Country"])
    break
# Out:
# 0 Afghanistan

# %%
'''df_obesity.set_index("Year")

Esse trecho muda o índice do DataFrame, substituindo o índice padrão (0,1,2,...) pela coluna "Year".

Ou seja, em vez de cada linha ser identificada pelo número da linha, ela será identificada pelo ano correspondente.

Importante: se você não usar inplace=True, isso não altera o DataFrame original, apenas retorna uma nova versão com "Year" como índice.

.to_dict()

Converte o DataFrame em um dicionário de dicionários (ou listas, dependendo do parâmetro orient que você usar).

Por padrão, to_dict() usa orient="dict", que gera um dicionário onde:

as chaves são os nomes das colunas,

os valores são dicionários com os índices como chave e os valores das células como valor.'''
df_obesity.set_index("Year").to_dict()
# Out:
# {'Unnamed: 0': {1975: 24446,
#   1976: 24449,
#   1977: 24452,
#   1978: 24455,
#   1979: 24458,
#   1980: 24461,
#   1981: 24464,
#   1982: 24467,
#   1983: 24470,
#   1984: 24473,
#   1985: 24476,
#   1986: 24479,
#   1987: 24482,
#   1988: 24485,
#   1989: 24488,
#   1990: 24491,
#   1991: 24494,
#   1992: 24497,
#   1993: 24500,
#   1994: 24503,
#   1995: 24506,
#   1996: 24509,
#   1997: 24512,
#   1998: 24515,
#   1999: 24518,
#   2000: 24521,
#   2001: 24524,
#   2002: 24527,
#   2003: 24530,
#   2004: 24533,
#   2005: 24536,
#   2006: 24539,
#   2007: 24542,
#   2008: 24545,
#   2009: 24548,
#   2010: 24551,
#   2011: 24554,
#   2012: 24557,
#   2013: 24560,
#   2014: 24563,
#   2015: 24566,
#   2016: 24569},
#  'Country': {1975: 'Zimbabwe',
#   1976: 'Zimbabwe',
#   1977: 'Zimbabwe',
#   1978: 'Zimbabwe',
#   1979: 'Zimbabwe',
#   1980: 'Zimbabwe',
#   1981: 'Zimbabwe',
#   1982: 'Zimbabwe',
#   1983: 'Zimbabwe',
#   1984: 'Zimbabwe',
#   1985: 'Zimbabwe',
# ...

# %%
# acessa o cicionário mostrando apenas o country
df_obesity.set_index("Year").to_dict()["Country"]
# Out:
# {1975: 'Zimbabwe',
#  1976: 'Zimbabwe',
#  1977: 'Zimbabwe',
#  1978: 'Zimbabwe',
#  1979: 'Zimbabwe',
#  1980: 'Zimbabwe',
#  1981: 'Zimbabwe',
#  1982: 'Zimbabwe',
#  1983: 'Zimbabwe',
#  1984: 'Zimbabwe',
#  1985: 'Zimbabwe',
#  1986: 'Zimbabwe',
#  1987: 'Zimbabwe',
#  1988: 'Zimbabwe',
#  1989: 'Zimbabwe',
#  1990: 'Zimbabwe',
#  1991: 'Zimbabwe',
#  1992: 'Zimbabwe',
#  1993: 'Zimbabwe',
#  1994: 'Zimbabwe',
#  1995: 'Zimbabwe',
#  1996: 'Zimbabwe',
#  1997: 'Zimbabwe',
#  1998: 'Zimbabwe',
#  1999: 'Zimbabwe',
#  2000: 'Zimbabwe',
#  2001: 'Zimbabwe',
#  2002: 'Zimbabwe',
#  2003: 'Zimbabwe',
#  2004: 'Zimbabwe',
#  2005: 'Zimbabwe',
#  2006: 'Zimbabwe',
#  2007: 'Zimbabwe',
#  2008: 'Zimbabwe',
#  2009: 'Zimbabwe',
#  2010: 'Zimbabwe',
#  2011: 'Zimbabwe',
#  2012: 'Zimbabwe',
#  2013: 'Zimbabwe',
#  2014: 'Zimbabwe',
#  2015: 'Zimbabwe',
#  2016: 'Zimbabwe'}

# %% [markdown]
# - Limpe os dados do DataFrame, criando uma coluna de nome 'Obesity' que conterá os valores de obesidade. Transforme em float as colunas que porventura foram importadas como string.

# %%
df_obesity = pd.read_csv("Datasets/obesity_cleaned.csv")

# 1. Criar a coluna 'Obesity' pegando apenas o número antes do espaço
#    - split(" ") separa em ["0.5", "[0.2-1.1]"]
#    - [0] pega o primeiro elemento da lista
df_obesity["Obesity"] = df_obesity["Obesity (%)"].str.split(" ").str[0]

# 2. Converter para float
# df_obesity["Obesity"] = df_obesity["Obesity"].astype(float)
df_obesity["Obesity"] = pd.to_numeric(df_obesity["Obesity"], errors="coerce")

df_obesity.dropna()

df_obesity = df_obesity.loc[:, ~df_obesity.columns.str.contains("^Unnamed")]  # remove colunas cujo nome começa com "Unnamed"



# Extrai o primeiro número dentro dos colchetes (limite inferior) e cria a coluna Obesity_min
df_obesity["Obesity_min"] = df_obesity["Obesity (%)"].str.extract(r"\[(\d+\.\d+)" )

# Extrai o número após o hífen dentro dos colchetes (limite superior) e cria a coluna Obesity_max
df_obesity["Obesity_max"] = df_obesity["Obesity (%)"].str.extract(r"-(\d+\.\d+)\]")

df_obesity[["Obesity_min", "Obesity_max"]] = df_obesity[["Obesity_min", "Obesity_max"]].astype(float)

df_obesity = df_obesity.loc[:, ~df_obesity.columns.str.contains("(%)")]  # remove colunas cujo nome começa com "Unnamed"


print(df_obesity)
# Out:
#            Country  Year         Sex  Obesity  Obesity_min  Obesity_max
# 0      Afghanistan  1975  Both sexes      0.5          0.2          1.1
# 1      Afghanistan  1975        Male      0.2          0.0          0.6
# 2      Afghanistan  1975      Female      0.8          0.2          2.0
# 3      Afghanistan  1976  Both sexes      0.5          0.2          1.1
# 4      Afghanistan  1976        Male      0.2          0.0          0.7
# ...            ...   ...         ...      ...          ...          ...
# 24565     Zimbabwe  2015        Male      4.5          2.4          7.6
# 24566     Zimbabwe  2015      Female     24.8         18.9         31.3
# 24567     Zimbabwe  2016  Both sexes     15.5         12.0         19.2
# 24568     Zimbabwe  2016        Male      4.7          2.5          8.0
# 24569     Zimbabwe  2016      Female     25.3         19.1         32.0
#
# [24570 rows x 6 columns]
# ...

# %% [markdown]
# - Qual o percentual médio de obesidade por sexo no mundo no ano de 2015?

# %%
df_2015 = df_obesity[df_obesity["Year"] == 2015]

df_2015.groupby("Sex")["Obesity"].mean()
# Out:
# Sex
# Both sexes    19.508377
# Female        22.899476
# Male          15.980628
# Name: Obesity, dtype: float64

# %% [markdown]
# - Quais são os 5 países com a maior e a menor taxa de aumento nos índices de obesidade no período observado?

# %%
# Considerar apenas "Both sexes" para não duplicar países
df_both = df_obesity[df_obesity["Sex"] == "Both sexes"]
print(df_both)

# Obter obesidade inicial e final por país
df_growth = df_both.groupby("Country").agg(
    Obesity_start=("Obesity", "first"),
    Obesity_end=("Obesity", "last")
)

df_growth.head(10)
# Out:
#            Country  Year         Sex  Obesity  Obesity_min  Obesity_max
# 0      Afghanistan  1975  Both sexes      0.5          0.2          1.1
# 3      Afghanistan  1976  Both sexes      0.5          0.2          1.1
# 6      Afghanistan  1977  Both sexes      0.6          0.2          1.2
# 9      Afghanistan  1978  Both sexes      0.6          0.2          1.3
# 12     Afghanistan  1979  Both sexes      0.6          0.3          1.3
# ...            ...   ...         ...      ...          ...          ...
# 24555     Zimbabwe  2012  Both sexes     14.3         11.4         17.6
# 24558     Zimbabwe  2013  Both sexes     14.6         11.5         18.0
# 24561     Zimbabwe  2014  Both sexes     14.9         11.7         18.4
# 24564     Zimbabwe  2015  Both sexes     15.2         11.9         18.8
# 24567     Zimbabwe  2016  Both sexes     15.5         12.0         19.2
#
# [8190 rows x 6 columns]
#                      Obesity_start  Obesity_end
# Country
# ...

# %%
# Calcular aumento absoluto
df_growth["Obesity_increase"] = df_growth["Obesity_end"] - df_growth["Obesity_start"]

df_growth.head()
# Out:
#              Obesity_start  Obesity_end  Obesity_increase
# Country
# Afghanistan            0.5          5.5               5.0
# Albania                6.5         21.7              15.2
# Algeria                6.9         27.4              20.5
# Andorra               12.9         25.6              12.7
# Angola                 0.8          8.2               7.4

# %%
# Ordenar pelo aumento
top5 = df_growth.sort_values("Obesity_increase", ascending=False).head(5)
bottom5 = df_growth.sort_values("Obesity_increase", ascending=True).head(5)

print("Top 5 países com maior aumento:\n", top5)
print("\nTop 5 países com menor aumento:\n", bottom5)
# Out:
# Top 5 países com maior aumento:
#                Obesity_start  Obesity_end  Obesity_increase
# Country
# Tuvalu                 17.9         51.6              33.7
# Niue                   18.9         50.0              31.1
# Kiribati               15.9         46.0              30.1
# Tonga                  19.9         48.2              28.3
# Cook Islands           28.0         55.9              27.9
#
# Top 5 países com menor aumento:
#               Obesity_start  Obesity_end  Obesity_increase
# Country
# Viet Nam               0.1          2.1               2.0
# Singapore              3.0          6.1               3.1
# Japan                  1.0          4.3               3.3
# Bangladesh             0.2          3.6               3.4
# Timor-Leste            0.2          3.8               3.6

# %% [markdown]
# - Quais os países com maiores e menores níveis percetuais de obesidade em 2015?

# %%
df_2015.head(100)
# Out:
#                        Country  Year         Sex  Obesity  Obesity_min  \
# 120                Afghanistan  2015  Both sexes      5.2          3.3
# 121                Afghanistan  2015        Male      3.0          1.3
# 122                Afghanistan  2015      Female      7.3          4.1
# 246                    Albania  2015  Both sexes     21.1         16.6
# 247                    Albania  2015        Male     20.9         14.4
# ...                        ...   ...         ...      ...          ...
# 4028                    Canada  2015      Female     28.8         24.0
# 4152  Central African Republic  2015  Both sexes      7.2          4.6
# 4153  Central African Republic  2015        Male      3.5          1.5
# 4154  Central African Republic  2015      Female     10.5          6.1
# 4278                      Chad  2015  Both sexes      5.8          4.0
#
#       Obesity_max
# 120           7.7
# 121           6.0
# 122          11.8
# 246          26.0
# ...

# %%
df_2015.groupby("Country")["Obesity"].mean().sort_values(ascending=True).head(1)
# Out:
# Country
# Viet Nam    1.966667
# Name: Obesity, dtype: float64

# %%
df_2015.groupby("Country")["Obesity"].mean().sort_values(ascending=False).head(1)
# Out:
# Country
# Nauru    60.666667
# Name: Obesity, dtype: float64

# %% [markdown]
# - Qual a diferença média percentual de obesidade entre sexos ao longo dos anos para o Brasil?

# %%
# Filtrar dados do Brasil
df_brazil = df_obesity[df_obesity["Country"] == "Brazil"]

# %%
# Pivot para ter colunas separadas por sexo
df_pivot = df_brazil.pivot(index="Year", columns="Sex", values="Obesity")
df_pivot.head()
# Out:
# Sex   Both sexes  Female  Male
# Year
# 1975         5.2     7.3   3.0
# 1976         5.5     7.6   3.2
# 1977         5.7     8.0   3.4
# 1978         6.0     8.3   3.6
# 1979         6.3     8.7   3.8

# %%
# Calcular diferença percentual (Female - Male)
df_pivot["Diff_Female_Male"] = df_pivot["Female"] - df_pivot["Male"]
df_pivot.head()
# Out:
# Sex   Both sexes  Female  Male  Diff_Female_Male
# Year
# 1975         5.2     7.3   3.0               4.3
# 1976         5.5     7.6   3.2               4.4
# 1977         5.7     8.0   3.4               4.6
# 1978         6.0     8.3   3.6               4.7
# 1979         6.3     8.7   3.8               4.9

# %%
# Diferença média ao longo dos anos
diff_media = df_pivot["Diff_Female_Male"].mean()
print(f"Diferença média percentual de obesidade entre sexos no Brasil: {diff_media:.2f}%")
# Out:
# Diferença média percentual de obesidade entre sexos no Brasil: 6.18%

# %% [markdown]
# - Você conseguiria plotar um gráfico mostrando a evolução da obesidade para ambos sexos no mundo?

# %%
import matplotlib.pyplot as plt

# %%
# Calcular a obesidade média global por ano e por sexo
df_global = df_obesity.groupby(["Year", "Sex"])["Obesity"].mean().unstack()
df_global.head()
# Out:
# Sex   Both sexes    Female      Male
# Year
# 1975    6.510995  8.850262  4.076440
# 1976    6.737696  9.120419  4.251832
# 1977    6.962304  9.396859  4.427225
# 1978    7.193717  9.676963  4.612565
# 1979    7.430890  9.963351  4.805236

# %%
# Plotar o gráfico
plt.figure(figsize=(10,6))
plt.plot(df_global.index, df_global["Male"], marker='o', label="Homens")
plt.plot(df_global.index, df_global["Female"], marker='o', label="Mulheres")
plt.plot(df_global.index, df_global["Both sexes"], marker='o', label="Ambos os sexos", linestyle='--')
plt.title("Evolução da Obesidade Média Global por Sexo")
plt.xlabel("Ano")
plt.ylabel("Obesidade (%)")
plt.legend()
plt.grid(True)
plt.show()

# %%
df_both.plot()

# %% [markdown]
# ## Perguntas - GDP Per Person (1901-2011)

# %%
df_gdp = pd.read_csv("Datasets/GDP.csv", decimal=".")
df_gdp
# Out:
#           Country                                         Region      Year  \
# 0     Afghanistan  Middle East, North Africa, and Greater Arabia  1/1/1901
# 1     Afghanistan  Middle East, North Africa, and Greater Arabia  1/1/1906
# 2     Afghanistan  Middle East, North Africa, and Greater Arabia  1/1/1911
# 3     Afghanistan  Middle East, North Africa, and Greater Arabia  1/1/1916
# 4     Afghanistan  Middle East, North Africa, and Greater Arabia  1/1/1921
# ...           ...                                            ...       ...
# 4414     Zimbabwe                             Sub-Saharan Africa  1/1/1991
# 4415     Zimbabwe                             Sub-Saharan Africa  1/1/1996
# 4416     Zimbabwe                             Sub-Saharan Africa  1/1/2001
# 4417     Zimbabwe                             Sub-Saharan Africa  1/1/2006
# 4418     Zimbabwe                             Sub-Saharan Africa  1/1/2011
#
#        GDP_pp
# 0      613.99
# 1      624.04
# 2      634.25
# ...

# %% [markdown]
# - Limpe o conjunto de dados, convertendo strings em datas ou float, quando necessário.

# %%
df_gdp["Year"] = df_gdp["Year"].apply(lambda x: int(x.split("/")[-1])) # retorna uma lista em que quero apenas o último elemento

# %%
df_gdp.head()
# Out:
#        Country                                         Region  Year   GDP_pp
# 0  Afghanistan  Middle East, North Africa, and Greater Arabia  1901   613.99
# 1  Afghanistan  Middle East, North Africa, and Greater Arabia  1906   624.04
# 2  Afghanistan  Middle East, North Africa, and Greater Arabia  1911   634.25
# 3  Afghanistan  Middle East, North Africa, and Greater Arabia  1916   647.28
# 4  Afghanistan  Middle East, North Africa, and Greater Arabia  1921   662.40

# %% [markdown]
# - Você conseguiria informar o primeiro valor registrado de cada país?

# %%
df_gdp["gdp_pp"] = df_gdp[" GDP_pp "].replace(",", "")
#del df_gdp[" GDP_pp "]

# %%
df_gdp.head(1000)
# Out:
#          Country                                         Region  Year  \
# 0    Afghanistan  Middle East, North Africa, and Greater Arabia  1901
# 1    Afghanistan  Middle East, North Africa, and Greater Arabia  1906
# 2    Afghanistan  Middle East, North Africa, and Greater Arabia  1911
# 3    Afghanistan  Middle East, North Africa, and Greater Arabia  1916
# 4    Afghanistan  Middle East, North Africa, and Greater Arabia  1921
# ..           ...                                            ...   ...
# 995   Czech Rep.                                         Europe  1931
# 996   Czech Rep.                                         Europe  1936
# 997   Czech Rep.                                         Europe  1941
# 998   Czech Rep.                                         Europe  1946
# 999   Czech Rep.                                         Europe  1951
#
#         GDP_pp       gdp_pp
# 0       613.99      613.99
# 1       624.04      624.04
# 2       634.25      634.25
# ...

# %%
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4419 entries, 0 to 4418
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   4419 non-null   object
#  1   Region    4419 non-null   object
#  2   Year      4419 non-null   int64
#  3    GDP_pp   4419 non-null   object
#  4   gdp_pp    4419 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 172.7+ KB

# %%
#df_gdp["gdp_pp1"] = df_gdp["gdp_pp"].apply(lambda x: float(x.split(" ")[1])).replace(",", "")
df_gdp["gdp_pp2"] = df_gdp[" GDP_pp "].apply(lambda x: float(x.split(" ")[1].replace(",", "")))
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4419 entries, 0 to 4418
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   4419 non-null   object
#  1   Region    4419 non-null   object
#  2   Year      4419 non-null   int64
#  3    GDP_pp   4419 non-null   object
#  4   gdp_pp    4419 non-null   object
#  5   gdp_pp2   4419 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 207.3+ KB

# %%
df_gdp.groupby("Country").min()["Year"]
# Out:
# Country
# Afghanistan    1901
# Albania        1901
# Algeria        1901
# Andorra        1901
# Angola         1901
#                ...
# Venezuela      1901
# Vietnam        1901
# Yemen, Rep.    1901
# Zambia         1901
# Zimbabwe       1901
# Name: Year, Length: 193, dtype: int64

# %%
df_gdp.groupby("Country").min()["Year"].isna().sum()
# Out:
# 0

# %%
df_gdp.groupby("Country").min()["Year"].value_counts()
# Out:
# Year
# 1901    192
# 1991      1
# Name: count, dtype: int64

# %%
df_gdp.groupby("Country").min()["Year"][df_gdp.groupby("Country").min()["Year"] == 1991]
# Out:
# Country
# Kosovo    1991
# Name: Year, dtype: int64

# %% [markdown]
# - Informe as regiões com maiores crescimentos de PIB per capita no século passado.

# %%
df_gdp[df_gdp["Year"] < 2000]["Year"].max()
# Out:
# 1996

# %%
df_gdp_start = df_gdp[(df_gdp["Year"] == 1901)]
df_gdp_end = df_gdp[(df_gdp["Year"] == 1996)]

# %%
df_gdp_start
# Out:
#           Country                                         Region  Year  \
# 0     Afghanistan  Middle East, North Africa, and Greater Arabia  1901
# 23        Albania                                         Europe  1901
# 46        Algeria  Middle East, North Africa, and Greater Arabia  1901
# 69        Andorra                                         Europe  1901
# 92         Angola                             Sub-Saharan Africa  1901
# ...           ...                                            ...   ...
# 4304    Venezuela                                  South America  1901
# 4327      Vietnam                                           Asia  1901
# 4350  Yemen, Rep.  Middle East, North Africa, and Greater Arabia  1901
# 4373       Zambia                             Sub-Saharan Africa  1901
# 4396     Zimbabwe                             Sub-Saharan Africa  1901
#
#          GDP_pp       gdp_pp  gdp_pp2
# 0        613.99      613.99    613.99
# ...

# %%
df_gdp_end
# Out:
#           Country                                         Region  Year  \
# 19    Afghanistan  Middle East, North Africa, and Greater Arabia  1996
# 42        Albania                                         Europe  1996
# 65        Algeria  Middle East, North Africa, and Greater Arabia  1996
# 88        Andorra                                         Europe  1996
# 111        Angola                             Sub-Saharan Africa  1996
# ...           ...                                            ...   ...
# 4323    Venezuela                                  South America  1996
# 4346      Vietnam                                           Asia  1996
# 4369  Yemen, Rep.  Middle East, North Africa, and Greater Arabia  1996
# 4392       Zambia                             Sub-Saharan Africa  1996
# 4415     Zimbabwe                             Sub-Saharan Africa  1996
#
#           GDP_pp        gdp_pp   gdp_pp2
# 19        617.91       617.91     617.91
# ...

# %%
df_gdp_start["gdp_pp"] = df_gdp_start["gdp_pp2"]
df_gdp_end["gdp_pp"] = df_gdp_end["gdp_pp2"]
df_gdp["gdp_pp"] = df_gdp["gdp_pp2"]

df_gdp_end.groupby("Region")["gdp_pp"].mean()
# Out:
# C:\Users\Thiago\AppData\Local\Temp\ipykernel_24512\740718974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_start["gdp_pp"] = df_gdp_start["gdp_pp2"]
# C:\Users\Thiago\AppData\Local\Temp\ipykernel_24512\740718974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_end["gdp_pp"] = df_gdp_end["gdp_pp2"]
# Region
# Asia                                              7311.992963
# Australia and Oceania                             7402.546000
# ...

# %%
((df_gdp_end.groupby("Region")["gdp_pp"].mean() / df_gdp_start.groupby("Region")["gdp_pp"].mean() - 1) * 100).sort_values(ascending=False)
# Out:
# Region
# Middle East, North Africa, and Greater Arabia    857.215950
# Asia                                             711.761516
# Europe                                           594.046167
# North America                                    589.760175
# Central America and the Caribbean                406.426789
# Australia and Oceania                            396.075383
# South America                                    312.123735
# Sub-Saharan Africa                               248.633780
# Name: gdp_pp, dtype: float64

# %% [markdown]
# - Preecha os anos ausentes em cada país com uma estimativa, baseada na diferença entre o próximo registro e o anterior.

# %%
df_gdp.head()
# Out:
#        Country                                         Region  Year   GDP_pp   \
# 0  Afghanistan  Middle East, North Africa, and Greater Arabia  1901   613.99
# 1  Afghanistan  Middle East, North Africa, and Greater Arabia  1906   624.04
# 2  Afghanistan  Middle East, North Africa, and Greater Arabia  1911   634.25
# 3  Afghanistan  Middle East, North Africa, and Greater Arabia  1916   647.28
# 4  Afghanistan  Middle East, North Africa, and Greater Arabia  1921   662.40
#
#      gdp_pp  gdp_pp2
# 0   613.99    613.99
# 1   624.04    624.04
# 2   634.25    634.25
# 3   647.28    647.28
# 4   662.40    662.40

# %%
arr_years = np.arange(df_gdp["Year"].min(), df_gdp["Year"].max())
df_all_years = pd.DataFrame(arr_years, columns=["Year"])
df_all_years.index = df_all_years["Year"]

df_years_off = ~df_all_years["Year"].isin(df_gdp["Year"])
df_years_off = df_years_off[df_years_off].index

# %%
df_gdp = df_gdp.sort_values(["Country", "Year"])

df_gdp["delta_gdp"] = df_gdp["gdp_pp"] - df_gdp["gdp_pp"].shift(1)
df_gdp["delta_year"] = df_gdp["Year"] - df_gdp["Year"].shift(1)
df_gdp["gdp_year"] = (df_gdp["delta_gdp"] / df_gdp["delta_year"]).shift(-1)

# %%
df_gdp["next_year"] = df_gdp["Year"].shift(-1)
del df_gdp["delta_gdp"], df_gdp["delta_year"]

# %%
df_new_data = pd.DataFrame()

for idx, row in df_gdp.iterrows():
    if row["Year"] == 2011:
        continue
    
    # print(idx, row)
    year_to_add = df_years_off[(df_years_off < row["next_year"]) & (df_years_off >row["Year"])]
    
    for new_year in year_to_add:
        add_row = row.copy()
        add_row["gdp_pp"] = (new_year - add_row["Year"]) * add_row["gdp_year"] + add_row["gdp_pp"]
        add_row["Year"] = new_year
        df_new_data["kind"] = "estimated"
        df_new_data = pd.concat([df_new_data, add_row.to_frame().transpose()])

# %%
df_gdp.iloc[100:].head(10)
# Out:
#     Country              Region  Year     GDP_pp    gdp_pp  gdp_pp2  gdp_year  \
# 100  Angola  Sub-Saharan Africa  1941   2,170.80   2170.80  2170.80   119.530
# 101  Angola  Sub-Saharan Africa  1946   2,768.45   2768.45  2768.45   134.490
# 102  Angola  Sub-Saharan Africa  1951   3,440.90   3440.90  3440.90    21.628
# 103  Angola  Sub-Saharan Africa  1956   3,549.04   3549.04  3549.04   182.958
# 104  Angola  Sub-Saharan Africa  1961   4,463.83   4463.83  4463.83   168.862
# 105  Angola  Sub-Saharan Africa  1966   5,308.14   5308.14  5308.14    43.614
# 106  Angola  Sub-Saharan Africa  1971   5,526.21   5526.21  5526.21  -495.178
# 107  Angola  Sub-Saharan Africa  1976   3,050.32   3050.32  3050.32   -19.382
# 108  Angola  Sub-Saharan Africa  1981   2,953.41   2953.41  2953.41  -146.560
# 109  Angola  Sub-Saharan Africa  1986   2,220.61   2220.61  2220.61   102.048
#
#      next_year
# 100     1946.0
# 101     1951.0
# 102     1956.0
# 103     1961.0
# 104     1966.0
# ...

# %%
df_gdp = pd.concat([df_gdp, df_new_data]).sort_values(["Country", "Year"])
df_gdp["kind"].fillna("real", inplace=True)
df_gdp.index = df_gdp["Year"]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(20, 5))
df_gdp[(df_gdp["kind"] == "real") & (df_gdp["Country"] == "United States")].plot(kind="scatter", y="gdp_pp", x="Year", ax=ax)
df_gdp[(df_gdp["kind"] == "estimated") & (df_gdp["Country"] == "United States")].plot(kind="scatter", y="gdp_pp", x="Year", ax=ax, color="red")
# Out:
# <Axes: xlabel='Year', ylabel='gdp_pp'>

# %% [markdown]
# ### DESAFIOS
# - Você conseguiria criar um mapa do gdp ou da obesidade no mundo ao longo dos anos?

# %%
df_gdp[df_gdp["kind"] == "real"].reset_index(drop=True).head(5)
# Out:
#        Country                                         Region  Year   GDP_pp   \
# 0  Afghanistan  Middle East, North Africa, and Greater Arabia  1901   613.99
# 1  Afghanistan  Middle East, North Africa, and Greater Arabia  1906   624.04
# 2  Afghanistan  Middle East, North Africa, and Greater Arabia  1911   634.25
# 3  Afghanistan  Middle East, North Africa, and Greater Arabia  1916   647.28
# 4  Afghanistan  Middle East, North Africa, and Greater Arabia  1921   662.40
#
#    gdp_pp gdp_pp2 gdp_year next_year  kind
# 0  613.99  613.99     2.01    1906.0  real
# 1  624.04  624.04    2.042    1911.0  real
# 2  634.25  634.25    2.606    1916.0  real
# 3  647.28  647.28    3.024    1921.0  real
# 4   662.4   662.4    3.094    1926.0  real

# %%
df_gdp["Year"] = df_gdp["Year"].astype(int)
df_gdp["gdp_pp"] = df_gdp["gdp_pp"].astype(float)

# %%
import plotly.express as px

df = px.data.gapminder()
dict_iso_alpha = df.set_index("country").to_dict()["iso_alpha"]
dict_num = {j: i for i, j in enumerate(df_gdp["Country"].unique())}

df_gdp["iso_alpha"] = df_gdp["Country"].map(dict_iso_alpha)
df_gdp["iso_num"] = df_gdp["Country"].map(dict_num)

fig = px.choropleth(df_gdp[df_gdp["kind"] == "real"].reset_index(drop=True), locations="iso_alpha", color="gdp_pp", hover_name="Country", animation_frame="Year")

fig.update_layout(height=600)
fig.show()

# %% [markdown]
# - Há uma relação entre níveis de obesidade e gdp per capita?

# %%
df_obesity["country-year"] = df_obesity["Country"] + "-" + df_obesity.reset_index()["Year"].apply(lambda x: str(int(x))).values
dict_obesity_year = df_obesity.set_index("country-year").to_dict()["Obesity"]

# %%
df_gdp["country-year"] = df_gdp["Country"] + "-" + df_gdp["Year"].apply(lambda x: str(x)).values
df_gdp["Obesity"] = df_gdp["country-year"].map(dict_obesity_year)

# %%
# df_gdp.dropna(inplace=True)

# %%
df_gdp_clean = df_gdp.dropna()

# %%
countries = df_gdp_clean["Country"].unique()

# %%
corr_list = []
for country in countries:
    corr_list += [df_gdp_clean[df_gdp_clean["Country"] == country][["Obesity", "gdp_pp"]].corr().iloc[0, 1]]

df_corr = pd.Series(corr_list, index=countries)

# %%
df_corr.mean()
# Out:
# 0.5156020945367675

# %%
df_corr.std()
# Out:
# 0.6523066623226486

# %%
df_corr.sort_values().plot()
# Out:
# <Axes: >

# %%
country = "Australia"
fig, ax = plt.subplots()
df_gdp_clean[df_gdp_clean["Country"] == country][["Obesity"]].plot(ax=ax)
ax2 = ax.twinx()
df_gdp_clean[df_gdp_clean["Country"] == country][["gdp_pp"]].plot(ax=ax2, color="red")
# Out:
# <Axes: xlabel='Year'>

# %%
df_gdp_clean
# Out:
#           Country                                         Region  Year  \
# Year
# 1975  Afghanistan  Middle East, North Africa, and Greater Arabia  1975
# 1976  Afghanistan  Middle East, North Africa, and Greater Arabia  1976
# 1977  Afghanistan  Middle East, North Africa, and Greater Arabia  1977
# 1978  Afghanistan  Middle East, North Africa, and Greater Arabia  1978
# 1979  Afghanistan  Middle East, North Africa, and Greater Arabia  1979
# ...           ...                                            ...   ...
# 2006     Zimbabwe                             Sub-Saharan Africa  2006
# 2007     Zimbabwe                             Sub-Saharan Africa  2007
# 2008     Zimbabwe                             Sub-Saharan Africa  2008
# 2009     Zimbabwe                             Sub-Saharan Africa  2009
# 2010     Zimbabwe                             Sub-Saharan Africa  2010
#
#        GDP_pp    gdp_pp gdp_pp2 gdp_year next_year       kind iso_alpha  \
# Year
# ...

# %%
df_gdp_clean.reset_index(drop=True).groupby("Year")[["Obesity", "gdp_pp"]].mean().corr().iloc[0, 1]
# Out:
# 0.9693775432125091
